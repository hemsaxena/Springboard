# %% [markdown]
# #### During this step I will investigate the relationships between features, and attempt to understand the core characteristics of the data. I will be using different figures and plots to deepen this understanding.

# %%
#loading the libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import pandas as pd
import os

# %%
#changing the working directory
os.chdir('C:\\MY FOLDER\\SpringBoard\\CapstoneProject2\\')

#Listing the contents of the directory
os.listdir()
# Out:
# ['310_23498_compressed_creditcard.csv.zip',
#  'creditcard.csv',
#  'Documents',
#  'figures',
#  'models',
#  'step2_output_O.csv',
#  'step2_output_R.csv']

# %%
#loading the csv file
df = pd.read_csv("step2_output_O.csv")
df.head()
# Out:
#    Elapsed Time        V1        V2        V3        V4        V5        V6  \
# 0           0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1           0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2           1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3           1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4           2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# # Building Data Profile Tables and Plots

# %%
df.describe()
# Out:
#         Elapsed Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.923752e-15  5.559442e-16 -8.769520e-15  2.759583e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.549320e-15  2.005278e-15 -1.695447e-15 -1.933764e-16 -3.136288e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.540693e-16  7.961936e-16  5.402018e-16  4.459446e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.446667e-15  1.705578e-15 -3.668456e-16 -1.203990e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df.dtypes
# Out:
# Elapsed Time    float64
# V1              float64
# V2              float64
# V3              float64
# V4              float64
# V5              float64
# V6              float64
# V7              float64
# V8              float64
# V9              float64
# V10             float64
# V11             float64
# V12             float64
# V13             float64
# V14             float64
# V15             float64
# V16             float64
# V17             float64
# V18             float64
# V19             float64
# V20             float64
# V21             float64
# V22             float64
# V23             float64
# V24             float64
# V25             float64
# V26             float64
# V27             float64
# V28             float64
# Amount          float64
# Class             int64
# dtype: object

# %%
#df.plot.hist(bins=2,figsize=(15,10))
df.hist(bins=10,figsize=(30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADA6397C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAC14248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAC49E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAC82C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAE0BAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAE46988>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAE7F848>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAEB9588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAEB9788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAEF2688>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAF64208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAF96F48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAFCFEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB00AD08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB043B88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB07BA48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB0B48C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB0ED748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB127588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB161408>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB19A2C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB1D4188>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB207FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB23FDC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB278C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB2B1AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB2EA988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB325808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB35E648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB3974C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB3CCE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB404C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB43CA88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB474888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADAF6AEC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024ADB217988>]],
#       dtype=object)

# %%
sns.countplot(data=df,
            x='Class',label='Count')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
#plotting amounts of transaction grouped by each class
df.groupby('Class')['Amount'].plot(title='Transaction Amount Per Class', legend=True,figsize=(10,5))
# Out:
# Class
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Amount, dtype: object

# %% [markdown]
# The fraudulent transaction amounts are relatively in a very low range of values as compared to non-fraudulent transactions.

# %%
#plotting amounts of transaction grouped by each classboxplot = df.boxplot(grid=False, vert=False,fontsize=15, figsize=(15, 15))
df.groupby('Class')['Elapsed Time'].plot(title='Transaction Time Per Class', legend=True,figsize=(10,5))
# Out:
# Class
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Elapsed Time, dtype: object

# %%
boxplot = df.boxplot(grid=False, vert=False,fontsize=15, figsize=(15, 15))

# %%
corr = df.corr(method="pearson")
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col1 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col2 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col5 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col7 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col8 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col9 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col10 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col12 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col14 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col16 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col17 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col18 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col19 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col20 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col21 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col22 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col23 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col25 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col26 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col27 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col28 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col29 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row0_col30 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col0 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col2 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col4 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col5 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col6 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col7 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col8 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col9 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col10 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col11 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col12 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col13 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col14 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col15 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col16 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col17 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col18 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col19 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col20 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col22 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col23 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col24 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col25 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col26 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col27 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_e974ce8c_c39f_11ea_8915_802bf9a47492row1_col28 {
#             background-color:  #
